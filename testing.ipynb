# %%
from app import data_clean_master
# Out:
# c:\Users\Ayush\OneDrive\Desktop\python\DataCleaningApp
# All modules imported successfully!
# ['.git', 'app.py', 'datacleaningapp.ipynb', 'delivery.xlsx', 'jaimahakalclean_data.csv', 'jaimahakalduplicate.csv', 'jan_salesclean_data.csv', 'jan_salesduplicate.csv', 'sales.xlsx', 'test.ipynb', 'testing.ipynb', 'walmart.xlsx', '__pycache__']

# %%
data_clean_master('almart.xlsx','bla')
# Out:
# thank you for giving the details
# Please wait for 1seconds! Checking file path
# Wrong File Path! Try again

# %%
data_clean_master('walmart.xlsx','walmart_clean.xlsx')
# Out:
# thank you for giving the details
# Please wait for 3seconds! Checking file path
# Dataset is excel file !
# Dataset contains tatal rows: 29
#  total colmn:9
# Dataset has total duplicates record:10
# Dataset has total mising value:14
# Dataset contains missing value by column
#  invoice_id         0
# branch             4
# city               0
# age               10
# gender             0
# total              0
# date               0
# payment_method     0
# rating             0
# dtype: int64
# Congratulation!
#  Your Dataset is clean now.
#  Number of rows :19
#  Number of columns:9
#  Your Dataset is Saved.
